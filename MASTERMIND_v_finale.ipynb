# %%
from tkinter import*
from random import shuffle #pour mélanger les résultats de la combinaison
from random import choice  #utile pour que l'ordinateur créer sa propre combinaison

global RED,YELLOW,GREEN,BLUE,WHITE,PURPLE,FUSHIA,ORANG

#cette fonction est le coeur du jeu, permettant de comparer deux listes et savoir si elles sont identiques ou non
def verification(combi,test):
    
    verif=[0]*len(test)
    Ex=[0]*10
    Re=[0]*10
    for i in range(len(test)):
        if test[i]==combi[i]:
            verif[i]=9
            Ex[test[i]]+=1
        else :
            verif[i]=0
    
    
    for i in range(len(combi)):
        if test[i] in combi and verif[i]!=9:
            if combi.count(test[i])<=Ex[test[i]]+Re[test[i]] or test.count(test[i])<=Ex[test[i]]+Re[test[i]]:
                pass
            else:
                Re[test[i]]+=1
                verif[i]=8
    return(verif)

#cette classe permet de transférer sans soucis les valeurs prise dans le menu dans le jeu
class Valeur():
    def __init__(self):
        self.tenta=3
        self.long=4
        self.color=4
        
Tentative=Valeur() #le nombre de tentative au minimum de 3
limite=Valeur() #la taille max de la combinaison allant de 4 à 7
NC=Valeur() #nombre de couleur disponible pour jouer, augmentant ainsi la difficulté au fil du nombre de couleurs allant de 4 à 8


taille=0 #ce compteur permet de gérer en entrée des combinaison le nombre de boule dans la combinaison par rapport à la limite imposer
combi=[] #cette liste vide se remplira quand le joueur ou l'ordi entrera le code secret à trouver
test=[] #cette liste vide se remplira quand le joueur essayera de deviner le code secret

#lié au bouton quitter du menu principal pour fermer le jeu
def quitter():
    menu.destroy()

#lié au bouton réglages du menu principal pour modifier le jeu à notre guise
def parametres():
    def confirm():
        Tentative.tenta=int(sp1.get())
        limite.long=int(sp2.get())
        NC.color=int(sp3.get())
        setting.destroy()
        
    setting=Tk()
    setting.geometry('275x375+546+196')
    setting.configure(bg='#A9A9A9')
    setting.attributes("-topmost", True)
    setting.overrideredirect(1)
    
    save=Button(setting,text='ENREGISTRER',width=26,height=2,bg='#696969',command=confirm)
    save.place(x=40,y=250)
    
    txt1=Label(setting,text='Nombres de tentatives :',bg='#A9A9A9')
    txt1.place(x=5,y=80)
    
    txt2=Label(setting,text='Longueur de la combinaison :',bg='#A9A9A9')
    txt2.place(x=5,y=120)
    
    txt3=Label(setting,text='Nombre de couleurs :',bg='#A9A9A9')
    txt3.place(x=5,y=160)
    
    sp1=Spinbox(setting,textvariable=Tentative,from_=Tentative.tenta,to=11)
    sp1.place(x=135,y=80)
    
    sp2=Spinbox(setting,textvariable=limite,from_=limite.long,to=7,width=14)
    sp2.place(x=170,y=120)
    
    sp3=Spinbox(setting,textvariable=NC, from_=NC.color,to=8)
    sp3.place(x=135,y=160)
    
    setting.mainloop()

#lié au bouton jouer du menu principal pour lancer le jeu
def jouer():
    global RED,YELLOW,GREEN,BLUE,WHITE,PURPLE,FUSHIA,ORANGE,NC
    global background,debut,Tentative,tentrest,valeur,cache,fenjeu,fonction
    
    def quitterjeux():
        menu.destroy()
        
    #fonction renvoyant toutes les réponses possible au joueur
    def reponse(xd,yd):
        global rep,value,taille,test,background,combi,Tentative,tentrest,cache,fenjeu
        Tentative.tenta-=1
        tentrest.destroy()
        tentrest=Label(background,text='Tentative restante(s) : '+str(Tentative.tenta),bg='#DEB887',font='Times 25')
        tentrest.place(x=967,y=200)
        if Tentative.tenta==0:
            if combi==test:
                fin=Label(background,text='BRAVO VOUS AVEZ GAGNÉ !!!',bg='orange',font='Times 30')
                fin.place(x=464,y=354)
                cache.destroy()
                value=20
            else:
                fin=Label(background,text='OH NON VOUS AVEZ PERDU !!!',bg='orange',font='Times 30')
                fin.place(x=464,y=310)
                cache.destroy()
                value=20
                        
        if combi==test:
                fin=Label(background,text='BRAVO VOUS AVEZ GAGNÉ !!!',bg='orange',font='Times 30')
                fin.place(x=464,y=354)
                cache.destroy()
                value=20
        rep=verification(combi,test)
        shuffle(rep)
        R=Canvas(background,width=70,height=10,bg='#1E6252')
        R.place(x=xd,y=yd)
        value+=1
        
        taille=0
        
        
        for j in rep:
            if j==9:
                B=Canvas(R,width=10,height=10,highlightthickness=1,highlightbackground='#1E6252',bg='#1E6252')
                B.pack(side=LEFT)
                B.create_image(5,5,image=black)
            elif j==8:
                W=Canvas(R,width=10,height=10,highlightthickness=1,highlightbackground='#1E6252',bg='#1E6252')
                W.pack(side=LEFT)
                W.create_image(5,5,image=lwhite)
            else:
                V=Canvas(R,width=10,height=10,highlightthickness=1,highlightbackground='black',bg='#1E6252')
                V.pack(side=LEFT)
        test=[]
         
    global value,rep,test,combi,taille
    #lié au bouton valider du plateau de jeu pour demander la vérification au code entre la saisie et le code secret
    def valider():
        global value,debut,cache,rep,test,combi,taille,Tentative 
        if limite.long==taille:
            if value==2:
                textS.destroy()
                cache=Canvas(fenjeu, width=430,height=60,bg='black')
                cache.place(x=465,y=50)
                Misc.lift(cache)
            
                debut=Label(fenjeu,text="Essayez de trouver la bonne combinaison !",bg='orange',font='Times 25')
                debut.pack()
                background.create_window(740,300, window=debut)
                taille=0
                value+=1
            
            elif value==3:
                debut.destroy()
                reponse(460,675)
            
            elif value==4:
                reponse(460,620)
            elif value==5:
                reponse(460,550)
            elif value==6:
                reponse(460,500)
            elif value==7:
                reponse(460,440)
            elif value==8:
                reponse(460,380)
            elif value==9:
                reponse(460,320)
            elif value==10:
                reponse(460,260)
            elif value==11:
                reponse(460,200)
            elif value==12:
                reponse(460,140)
            elif value==13:
                reponse(460,100)
           
    global rectangle,combi,test,taille,support0,support1,support2,combi,test,support3,support4,support5,support6,support7,support8,support9,support10
#lié au bouton annuler du jeu pour effacer et pouvoir recommencer sa ligne en cas d'erreur
    def annuler():
        global rectangle,taille,support0,support1,support2,combi,test,support3,support4,support5,support6,support7,support8,support9,support10
        if value==2:
            rectangle.destroy()
            rectangle=Canvas(fenjeu, width=430, height=60,bg='#1E6252')
            rectangle.place(x=465, y=50)
            taille=0
            combi=[]
        elif value==3:
            support0.destroy()
            support0=Canvas(background,width=430,height=60,bg='#DEB887')
            support0.place(x=10, y=650)
            taille=0
            test=[]
        elif value==4:
            support1.destroy()
            support1=Canvas(background,width=430,height=60,bg='#DEB887')
            support1.place(x=10, y=590)
            taille=0
            test=[]
        elif value==5:
            support2.destroy()
            support2=Canvas(background,width=430,height=60,bg='#DEB887')
            support2.place(x=10, y=530)
            taille=0
            test=[]
        elif value==6:
            support3.destroy()
            support3=Canvas(background,width=430,height=60,bg='#DEB887')
            support3.place(x=10, y=470)
            taille=0
            test=[]
        elif value==7:
            support4.destroy()
            support4=Canvas(background,width=430,height=60,bg='#DEB887')
            support4.place(x=10, y=410)
            taille=0
            test=[]
        elif value==8:
            support5.destroy()
            support5=Canvas(background,width=430,height=60,bg='#DEB887')
            support5.place(x=10, y=350)
            taille=0
            test=[]
        elif value==9:
            support6.destroy()
            support6=Canvas(background,width=430,height=60,bg='#DEB887')
            support6.place(x=10, y=290)
            taille=0
            test=[]
        elif value==10:
            support7.destroy()
            support7=Canvas(background,width=430,height=60,bg='#DEB887')
            support7.place(x=10, y=230)
            taille=0
            test=[]
        elif value==11:
            support8.destroy()
            support8=Canvas(background,width=430,height=60,bg='#DEB887')
            support8.place(x=10, y=170)
            taille=0
            test=[]
        elif value==12:
            support9.destroy()
            support9=Canvas(background,width=430,height=60,bg='#DEB887')
            support9.place(x=10, y=110)
            taille=0
            test=[]
        elif value==13:
            support10.destroy()
            support10=Canvas(background,width=430,height=60,bg='#DEB887')
            support10.place(x=10, y=50)
            taille=0
            test=[]       
                    
#fonction lié à toutes les fonctions couleurs pour afficher la couleur choisi à l'endroit ou il faut
    def couleur(canvas,clr,x):
        global taille,test,combi,limite,value
        cs=Canvas(canvas,width=58,height=58,bg='#DEB887')
        cs.pack(side=LEFT)
        cs.create_image(31,31,image=clr)
        test.append(x)
        taille+=1
#ces 8 fonctions sont liés aux boutons des couleurs afin de faire son choix lors de l'entrée d'une combinaison    
    def rouge():
        global combi
        global limite
        global taille,value
        if taille<limite.long:
            if value==2:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=RED)
                combi.append(0)
                taille+=1
            #entrez dans la combi secrete
            elif value==1:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=RED)
                combi.append(0)
                taille+=1
                #entrez dans la combi de test
            
            if value==3:
                couleur(support0,RED,0)
            elif value==4:
                couleur(support1,RED,0)
            elif value==5:
                couleur(support2,RED,0)
            elif value==6:
                couleur(support3,RED,0)
            elif value==7:
                couleur(support4,RED,0)
            elif value==8:
                couleur(support5,RED,0)
            elif value==9:
                couleur(support6,RED,0)
            elif value==10:
                couleur(support7,RED,0)
            elif value==11:
                couleur(support8,RED,0)
            elif value==12:
                couleur(support9,RED,0)
            elif value==13:
                couleur(support10,RED,0)
                
    def jaune():
        global combi
        global limite
        global taille
        if taille<limite.long:
            if value==2:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=YELLOW)
                combi.append(1)
                taille+=1
            
            elif value==1:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=YELLOW)
                combi.append(1)
                taille+=1
                
            elif value==3:
                couleur(support0,YELLOW,1)
            elif value==4:
                couleur(support1,YELLOW,1)
            elif value==5:
                couleur(support2,YELLOW,1)
            elif value==6:
                couleur(support3,YELLOW,1)
            elif value==7:
                couleur(support4,YELLOW,1)
            elif value==8:
                couleur(support5,YELLOW,1)
            elif value==9:
                couleur(support6,YELLOW,1)
            elif value==10:
                couleur(support7,YELLOW,1)
            elif value==11:
                couleur(support8,YELLOW,1)
            elif value==12:
                couleur(support9,YELLOW,1)
            elif value==13:
                couleur(support10,YELLOW,1)
            
    def vert():
        global combi
        global limite
        global taille
        if taille<limite.long:
            if value==2:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=GREEN)
                combi.append(2)
                taille+=1
          
            elif value==1:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=GREEN)
                combi.append(2)
                taille+=1
          
            elif value==3:
                couleur(support0,GREEN,2)
            elif value==4:
                couleur(support1,GREEN,2)
            elif value==5:
                couleur(support2,GREEN,2)
            elif value==6:
                couleur(support3,GREEN,2)
            elif value==7:
                couleur(support4,GREEN,2)
            elif value==8:
                couleur(support5,GREEN,2)
            elif value==9:
                couleur(support6,GREEN,2)
            elif value==10:
                couleur(support7,GREEN,2)
            elif value==11:
                couleur(support8,GREEN,2)
            elif value==12:
                couleur(support9,GREEN,2)
            elif value==13:
                couleur(support10,GREEN,2) 
     
    def bleu():
        global combi
        global limite
        global taille
        if taille<limite.long:
            if value==2:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=BLUE)
                combi.append(3)
                taille+=1
         
            elif value==1:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=BLUE)
                combi.append(3)
                taille+=1
        
            elif value==3:
                couleur(support0,BLUE,3)
            elif value==4:
                couleur(support1,BLUE,3)
            elif value==5:
                couleur(support2,BLUE,3)
            elif value==6:
                couleur(support3,BLUE,3)
            elif value==7:
                couleur(support4,BLUE,3)
            elif value==8:
                couleur(support5,BLUE,3)
            elif value==9:
                couleur(support6,BLUE,3)
            elif value==10:
                couleur(support7,BLUE,3)
            elif value==11:
                couleur(support8,BLUE,3)
            elif value==12:
                couleur(support9,BLUE,3)
            elif value==13:
                couleur(support10,BLUE,3)
            
    def orange():
        global combi
        global limite
        global taille
        if taille<limite.long:
            if value==2:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=ORANGE)
                combi.append(4)
                taille+=1
    
            elif value==1:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=ORANGE)
                combi.append(4)
                taille+=1
            
            elif value==3:
                couleur(support0,ORANGE,4)
            elif value==4:
                couleur(support1,ORANGE,4)
            elif value==5:
                couleur(support2,ORANGE,4)
            elif value==6:
                couleur(support3,ORANGE,4)
            elif value==7:
                couleur(support4,ORANGE,4)
            elif value==8:
                couleur(support5,ORANGE,4)
            elif value==9:
                couleur(support6,ORANGE,4)
            elif value==10:
                couleur(support7,ORANGE,4)
            elif value==11:
                couleur(support8,ORANGE,4)
            elif value==12:
                couleur(support9,ORANGE,4)
            elif value==13:
                couleur(support10,ORANGE,4)
            
    def blanc():
        global combi
        global limite
        global taille
        if taille<limite.long:
            if value==2:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=WHITE)
                combi.append(5)
                taille+=1
        
            elif value==1:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=WHITE)
                combi.append(5)
                taille+=1
           
            elif value==3:
                couleur(support0,WHITE,5)
            elif value==4:
                couleur(support1,WHITE,5)
            elif value==5:
                couleur(support2,WHITE,5)
            elif value==6:
                couleur(support3,WHITE,5)
            elif value==7:
                couleur(support4,WHITE,5)
            elif value==8:
                couleur(support5,WHITE,5)
            elif value==9:
                couleur(support6,WHITE,5)
            elif value==10:
                couleur(support7,WHITE,5)
            elif value==11:
                couleur(support8,WHITE,5)
            elif value==12:
                couleur(support9,WHITE,5)
            elif value==13:
                couleur(support10,WHITE,5)
                
    def violet():
        global combi
        global limite
        global taille
        if taille<limite.long:
            if value==2:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=PURPLE)
                combi.append(6)
                taille+=1
         
            elif value==1:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=PURPLE)
                combi.append(6)
                taille+=1
         
            elif value==3:
                couleur(support0,PURPLE,6)
            elif value==4:
                couleur(support1,PURPLE,6)
            elif value==5:
                couleur(support2,PURPLE,6)
            elif value==6:
                couleur(support3,PURPLE,6)
            elif value==7:
                couleur(support4,PURPLE,6)
            elif value==8:
                couleur(support5,PURPLE,6)
            elif value==9:
                couleur(support6,PURPLE,6)
            elif value==10:
                couleur(support7,PURPLE,6)
            elif value==11:
                couleur(support8,PURPLE,6)
            elif value==12:
                couleur(support9,PURPLE,6)
            elif value==13:
                couleur(support10,PURPLE,6)
            
    def fuschia():
        global combi
        global limite
        global taille
        if taille<limite.long:
            if value==2:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=FUSHIA)
                combi.append(7)
                taille+=1
         
            elif value==1:
                cs=Canvas(rectangle,width=58,height=58,bg='#1E6252')
                cs.pack(side=LEFT)
                cs.create_image(31,31,image=FUSHIA)
                combi.append(7)
                taille+=1
         
            elif value==3:
                couleur(support0,FUSHIA,7)
            elif value==4:
                couleur(support1,FUSHIA,7)
            elif value==5:
                couleur(support2,FUSHIA,7)
            elif value==6:
                couleur(support3,FUSHIA,7)
            elif value==7:
                couleur(support4,FUSHIA,7)
            elif value==8:
                couleur(support5,FUSHIA,7)
            elif value==9:
                couleur(support6,FUSHIA,7)
            elif value==10:
                couleur(support7,FUSHIA,7)
            elif value==11:
                couleur(support8,FUSHIA,7)
            elif value==12:
                couleur(support9,FUSHIA,7)
            elif value==13:
                couleur(support10,FUSHIA,7)
          
    #code graphique de la fenetre jeu       
    fenjeu=Toplevel()
    fenjeu.title("Mastermind")
    fenjeu.attributes('-fullscreen',True)
    
    #fond du plateau de jeu
    background=Canvas(fenjeu,bg='#1E6252')
    background.pack(fill=BOTH,expand=YES)
    
    #plateau ou on entrera les combinaisons
    plateau=background.create_rectangle(5,45,450,718,fill='#DEB887')
    
    #endroit ou on selectionne les boules en bas à droite
    Rboule=background.create_rectangle(910,384,1326,718,fill="#DEB887")    
    
    #en haut à droite contenant le bouton quitter et le nombre de tentatives
    CTentative=background.create_rectangle(910,50,1326,250,fill="#DEB887")

    #rectangle contenant la combinaison secrete à trouver    
    rectangle=Canvas(fenjeu, width=430, height=60,bg='#1E6252')
    rectangle.place(x=465, y=50)
    
    #canvas invisible pour entrez les combinaison
    support0=Canvas(background,width=430,height=60,bg='#DEB887')
    support0.place(x=10, y=650)
    
    support1=Canvas(background,width=430,height=60,bg='#DEB887')
    support1.place(x=10, y=590)
    
    support2=Canvas(background,width=430,height=60,bg='#DEB887')
    support2.place(x=10, y=530)
    
    support3=Canvas(background,width=430,height=60,bg='#DEB887')
    support3.place(x=10, y=470)
    
    support4=Canvas(background,width=430,height=60,bg='#DEB887')
    support4.place(x=10, y=410)
    
    support5=Canvas(background,width=430,height=60,bg='#DEB887')
    support5.place(x=10, y=350)
    
    support6=Canvas(background,width=430,height=60,bg='#DEB887')
    support6.place(x=10, y=290)
    
    support7=Canvas(background,width=430,height=60,bg='#DEB887')
    support7.place(x=10, y=230)
    
    support8=Canvas(background,width=430,height=60,bg='#DEB887')
    support8.place(x=10, y=170)
    
    support9=Canvas(background,width=430,height=60,bg='#DEB887')
    support9.place(x=10, y=110)
    
    support10=Canvas(background,width=430,height=60,bg='#DEB887')
    support10.place(x=10, y=50)
    
    #le diamètre de la boule ne doit excéder 279
    #ON CREER LES BOUTONS SERVANT A SELECTIONNER LES BOULES
    
    RED=PhotoImage(file='RED.png')
    btnRED=Button(fenjeu,image=RED,borderwidth=0,bg='#DEB887',command=rouge)
    
    YELLOW=PhotoImage(file='YELLOW.png')
    btnYELLOW=Button(fenjeu,image=YELLOW,borderwidth=0,bg='#DEB887',command=jaune)
    
    BLUE=PhotoImage(file='BLUE.png')
    btnBLUE=Button(fenjeu,image=BLUE,borderwidth=0,bg='#DEB887',command=bleu)
    
    GREEN=PhotoImage(file='GREEN.png')
    btnGREEN=Button(fenjeu,image=GREEN,borderwidth=0,bg='#DEB887',command=vert)
    
    ORANGE=PhotoImage(file='ORANGE.png')
    btnORANGE=Button(fenjeu,image=ORANGE,borderwidth=0,bg='#DEB887',command=orange)
    
    WHITE=PhotoImage(file='WHITE.png')
    btnWHITE=Button(fenjeu,image=WHITE,borderwidth=0,bg='#DEB887',command=blanc)
    
    PURPLE=PhotoImage(file='PURPLE.png')
    btnPURPLE=Button(fenjeu,image=PURPLE,borderwidth=0,bg='#DEB887',command=violet)
    
    FUSHIA=PhotoImage(file='FUSHIA.png')
    btnFUSHIA=Button(fenjeu,image=FUSHIA,borderwidth=0,bg='#DEB887',command=fuschia)

    #cette enchaînement de if, elif permet de tester la valeur de NC=Nombres Couleurs et génère une combinaison secrete en mode solo
    if NC.color==2:
        btnRED.place(x=1260,y=389)
        btnYELLOW.place(x=1202,y=389)
        fonctions=[rouge,jaune]
    
    elif NC.color==3:
        btnRED.place(x=1260,y=389)
        btnYELLOW.place(x=1202,y=389)
        btnBLUE.place(x=1144,y=389)
        fonctions=[rouge,jaune,bleu]
    
    elif NC.color==4:
        btnRED.place(x=1260,y=389)
        btnYELLOW.place(x=1202,y=389)
        btnBLUE.place(x=1144,y=389)
        btnGREEN.place(x=1086,y=389)
        fonctions=[rouge,jaune,vert,bleu]
    
    elif NC.color==5:
        btnRED.place(x=1260,y=389)
        btnYELLOW.place(x=1202,y=389)
        btnBLUE.place(x=1144,y=389)
        btnGREEN.place(x=1086,y=389)
        btnORANGE.place(x=1260,y=447)
        fonctions=[rouge,jaune,vert,bleu,orange]
    
    elif NC.color==6:
        btnRED.place(x=1260,y=389)
        btnYELLOW.place(x=1202,y=389)
        btnBLUE.place(x=1144,y=389)
        btnGREEN.place(x=1086,y=389)
        btnORANGE.place(x=1260,y=447)
        btnWHITE.place(x=1202,y=447)
        fonctions=[rouge,jaune,vert,bleu,orange,blanc]
    
    elif NC.color==7:
        btnRED.place(x=1260,y=389)
        btnYELLOW.place(x=1202,y=389)
        btnBLUE.place(x=1144,y=389)
        btnGREEN.place(x=1086,y=389)
        btnORANGE.place(x=1260,y=447)
        btnWHITE.place(x=1202,y=447)
        btnPURPLE.place(x=1144,y=447)
        fonctions=[rouge,jaune,vert,bleu,orange,blanc,violet]
    
    else:
        btnRED.place(x=1260,y=389)
        btnYELLOW.place(x=1202,y=389)
        btnBLUE.place(x=1144,y=389)
        btnGREEN.place(x=1086,y=389)
        btnORANGE.place(x=1260,y=447)
        btnWHITE.place(x=1202,y=447)
        btnPURPLE.place(x=1144,y=447)
        btnFUSHIA.place(x=1086,y=447)
        fonctions=[rouge,jaune,vert,bleu,orange,blanc,violet,fuschia]
        
    #les mini carré pour la vérification
    black=PhotoImage(file="black.png") #pour couleur bien placé
    
    lwhite=PhotoImage(file="lwhite.png") #pour couleur présente mais mal placé

    #ligne décorative
    ligne1=background.create_line(910,648,1326,648)
    
    #bouton valider pour valider notre entrée de combinaison
    Valider=Button(fenjeu,text='VALIDER',width=27,height=3,bg="green",command=valider)
    Valider.place(x=915,y=655)
    
    #bouton annuler si on s'est trompé en entrant une combinaison
    Annuler=Button(fenjeu,text='EFFACER',width=27,height=3,bg="gray",command=annuler)
    Annuler.place(x=1120,y=655)
    
    #bouton quitter pour quitter le jeu
    Quit=Button(fenjeu,text='QUITTER',width=30,height=3,bg='red',font='Calibri 10 bold',command=quitterjeux)
    Quit.place(x=1010,y=75)

    #Label pour prévenir le joueur du nombres de tentatives qu'il lui reste qui changera au fur et a mesure de la partie
    tentrest=Label(background,text='Tentative restante(s) : '+str(Tentative.tenta),bg='#DEB887',font='Times 25')
    tentrest.place(x=967,y=200)
    
    #si il y à 2 joueurs, on demande d'entrer une combinaison
    value=int(valeur.get())
    
    if value==2:
        textS=Label(fenjeu,text="Entrez votre combinaison secrète !",bg='orange',font='Times 25')
        textS.pack()
        background.create_window(700,300, window=textS)
    
    #si le joueur est seul, l'ordinateur s'occupe de génerer le code secret
    if value==1:
        j=0
        
        for j in range(limite.long):
            choice(fonctions)()
            
        cache=Canvas(fenjeu, width=430,height=60,bg='black')
        cache.place(x=467,y=50)
        value=3
    
    #annonce le début du jeu pour le joueur
    if value==3:
        debut=Label(fenjeu,text="Essayez de trouver la bonne combinaison !",bg='orange',font='Times 25')
        debut.pack()
        background.create_window(740,300, window=debut)
        taille=0
                
    fenjeu.mainloop()    

#Fenetre du menu  
menu=Tk()
menu.title("Menu principale")
menu.geometry('550x550+400+65')
menu.resizable(False,False)

#arrière plan
back=Canvas(menu, width=550, height=550,bg='black')
back.pack()

#planche rectangle contenant les boutons
planche=back.create_rectangle(137,100,412,475,fill='orange')

#valeur récupère l'infos du nombre de joueur dans la partie
valeur=IntVar()
valeur.set(1)

#Boutons radios permettant le choix unique entre 1 ou 2 joueurs
Bt2=Radiobutton(menu,text='2 joueurs',bg='orange',variable=valeur, value=2)
Bt1=Radiobutton(menu,text="VS ordinateur",bg="orange",variable=valeur, value=1)
Bt2.place(x=285,y=150)
Bt1.place(x=185,y=150)

#Boutons du menu
Play=Button(menu,text='JOUER',width=26,height=2,bg='green',command=jouer)
Play.place(x=180,y=200)

Regle=Button(menu,text='REGLAGES',width=26,height=2,bg='grey',command=parametres)
Regle.place(x=180,y=275)

Quit=Button(menu,text='QUITTER',width=26,height=2,bg='red',font='Calibri 10 bold',command=quitter)
Quit.place(x=180,y=350)

#Image du titre
logo=PhotoImage(file='titre.png')
titre=back.create_image(275,50,image=logo)

menu.mainloop()
